# %%
# !python finder.py -h
# Out:
# usage: finder.py [-h] [-j | -c | -cf | -ck] [-d DIR] [-f FILE] [-k KEYWORD]
#                  [-e ENCODING]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -j, --json
#   -c, --csv
#   -cf, --file_csv
#   -ck, --keyword_csv
#   -d DIR, --dir DIR
#   -f FILE, --file FILE
#   -k KEYWORD, --keyword KEYWORD
#   -e ENCODING, --encoding ENCODING

# %%
# !python finder.py -cf -d ./sample
# Out:
# ./sample/test.html.processed,1
# ./sample/sample.html,1
# ./sample/test.html,1
# ./sample/sample.html.processed,1

# %%
# !python finder.py -ck -d ./sample
# Out:
# 機能利用 ,<a href="http://invbrain.neuroinf.jp/modules/htmldocs/IVBPF/Engineering/Engineering_contents.html">機能利用 </a>,1
# フェロモン,<a href=https://invbrain.neuroinf.jp/modules/xwords/entry.php?entryID=5&categoryID=1 jplinker=True>フェロモン</a>,1
# ログイン,<a href="http://invbrain.neuroinf.jp/modules/xoonips/user.php"">ログイン</a>,1
# <img src="https://invbrain.neuroinf.jp/themes/IVBgentleness2/logo2.jpg">,<a href="https://invbrain.neuroinf.jp/"><img src="https://invbrain.neuroinf.jp/themes/IVBgentleness2/logo2.jpg"></a>,1
# データベース ,<a href="http://invbrain.neuroinf.jp/modules/htmldocs/IVBPF/Database/ivbpf.html">データベース </a>,1
# +,<a href="https://invbrain.neuroinf.jp/" onClick="return clickreturnvalue()" onMouseover="dropdownmenu(this, event, submenu0ja, '150px')" onMouseout="delayhidemenu()">+</a>,1
# この記事の1行目に飛ぶ,<a href="#top_of_pico_body">この記事の1行目に飛ぶ</a>,1
# リファレンス ,<a href="#">リファレンス </a>,1
# 情 報 ,<a href="http://invbrain.neuroinf.jp/modules/credits/">情 報 </a>,1
# ...
