# %% [markdown]
# # This is a test notebook for this project.

# %%
import re

# %%
import sys
print sys.version_info
# Out:
# sys.version_info(major=2, minor=7, micro=12, releaselevel='final', serial=0)
