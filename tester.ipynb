# %% [markdown]
# # Test "jp-linker"

# %% [markdown]
# jp-linker is written for python 3.

# %%
import sys
print(sys.version_info)
# Out:
# sys.version_info(major=3, minor=5, micro=1, releaselevel='final', serial=0)

# %% [markdown]
# ## run linker.py using test option.

# %%
# !python linker.py --test
# Out:
# ---TEST MODE---
# ./sample/sample.html is processed.

# %% [markdown]
# ## run linker.py
# Run in forest1988's environment, which has some data in database.
#
# <!> This program is in development, so there are some errors left.

# %%
# !python linker.py
# Out:
# # DATABASE SYSTEM: sqlite
# # DATABASE: sample
#
# ---Keywords and urls---
# (1, 'フェロモン', 'NONE', 1)
# (2, '触角葉', 'https://invbrain.neuroinf.jp/modules/htmldocs/IVBPF/Moth/Moth_antennal_lobe.html', 1)
# (3, 'カイコガ触覚葉', 'http://kaikoga.com', 1)
# (4, '触角', 'https://syokkaku', 0)
# (5, '無脊椎動物プラットフォーム', 'https://invbrain.neuroinf.jp/modules/htmldocs/IVBPF/Moth/Moth_antennal_lobe.html', 1)
# ERROR! The TABLE name of target file path is not correctly set.
# 	 Please check "settings.py"
# ./sample/sample.html is processed.
# ./sample/test.html is processed.

# %%
# !diff -u ./sample/test.html ./sample/test.html.processed
# Out:
# --- ./sample/test.html	2016-07-25 01:46:23.000000000 +0900
# +++ ./sample/test.html.processed	2016-07-25 02:19:40.000000000 +0900
# @@ -209,7 +209,7 @@
#        <TABLE border="1" width="800" height="58">
#          <TBODY>
#            <TR>
# -                <TH width="100" align="center">他の動物の触角葉</TH>
# +                <TH width="100" align="center">他の動物の<a href=https://invbrain.neuroinf.jp/modules/htmldocs/IVBPF/Moth/Moth_antennal_lobe.html jplinker=True>触角葉</a></TH>
#              <TD width="80" align="center"><A href="../Bee/Bee_antennal_lobe.html" target="_blank" style="color : blue;text-decoration : none;">セイヨウ<BR>
#              ミツバチ</A></TD>
#              <TD width="80" align="center"><A href="../Cricket/Cricket_antennal_lobe.html" target="_blank" style="color : blue;text-decoration : none;">クロ<BR>
# @@ -236,7 +236,7 @@
#        <TD width="659" height="37" colspan="5"></TD>
#      </TR>
#      <TR style="line-height:210%">
# ...
